# %% [markdown]
# ## Task 0
# ### Exercise 5 Completed by: Natalie Benoy
#
# We will use a dataset that tracks the number of flights between the US and other countries from
# 2010-2015. The data is split into multiple files, one for each year. The file contains three
# columns – destination country, origin country, and flight count. This dataset is pre-loaded in the Databricks File System DBFS. It can be found at: "dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/ "

# %%
# import statements
import pyspark.sql.functions as F
from pyspark.sql.types import *

# %% [markdown]
# ## Task 1

# %%
# 1a – View the contents of the data folder using a file system command

# %%
# %fs
ls dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2010-summary.csv</td><td>2010-summary.csv</td><td>7121</td><td>1522192049000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2011-summary.csv</td><td>2011-summary.csv</td><td>7069</td><td>1522192049000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2012-summary.csv</td><td>2012-summary.csv</td><td>6857</td><td>1522192049000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2013-summary.csv</td><td>2013-summary.csv</td><td>7020</td><td>1522192050000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2014-summary.csv</td><td>2014-summary.csv</td><td>6729</td><td>1522192050000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2015-summary.csv</td><td>2015-summary.csv</td><td>7080</td><td>1522192050000</td></tr></tbody></table></div>

# %%
#1b – Use the dbutils module and display function to view directory contents as a table 
display(dbutils.fs.ls("dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2010-summary.csv</td><td>2010-summary.csv</td><td>7121</td><td>1522192049000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2011-summary.csv</td><td>2011-summary.csv</td><td>7069</td><td>1522192049000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2012-summary.csv</td><td>2012-summary.csv</td><td>6857</td><td>1522192049000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2013-summary.csv</td><td>2013-summary.csv</td><td>7020</td><td>1522192050000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2014-summary.csv</td><td>2014-summary.csv</td><td>6729</td><td>1522192050000</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2015-summary.csv</td><td>2015-summary.csv</td><td>7080</td><td>1522192050000</td></tr></tbody></table></div>

# %% [markdown]
# ## Task 2

# %%
# 2a – Read the 2015 data in and save the file as flight2015DF
flight2015DF = spark.read.csv("/databricks-datasets/definitive-guide/data/flight-data/csv/2015-summary.csv", header = True, sep = ',', inferSchema = False)

# %%
# 2b – View the schema in tree format using printSchema() method of Spark DataFrame
flight2015DF.printSchema()
# Out:
# root
#  |-- DEST_COUNTRY_NAME: string (nullable = true)
#  |-- ORIGIN_COUNTRY_NAME: string (nullable = true)
#  |-- count: string (nullable = true)

# %%
# 2c – set option/parameter inferSchema to True, and re-read 2015 data 
flight2015DF = spark.read.csv("/databricks-datasets/definitive-guide/data/flight-data/csv/2015-summary.csv", header = True, sep = ',', inferSchema = True)

# %%
# 2d – View the schema in tree format using printSchema() method of Spark DataFrame
flight2015DF.printSchema()
# Out:
# root
#  |-- DEST_COUNTRY_NAME: string (nullable = true)
#  |-- ORIGIN_COUNTRY_NAME: string (nullable = true)
#  |-- count: integer (nullable = true)

# %%
# 2e – Read in another file, 2014 data, and save it in another DF, flight2014DF
flight2014DF = spark.read.csv("/databricks-datasets/definitive-guide/data/flight-data/csv/2014-summary.csv", header = True, sep = ',', inferSchema = True)

# %% [markdown]
# ## Task 3

# %%
# 3a – combine the two DFs created in Task 2 for years 2015 and 2014 together using the union() method of Spark DataFrame.
flight20142015DF = flight2014DF.union(flight2015DF)

# %%
# 3b – Print the number of rows from combining 2015 and 2104 files
flight20142015DF.count()
# Out:
# Out[10]: 497

# %%
# 3c – Combine data from all six input .csv files for 2010-2015
flightsAllDF = spark.read.csv("/databricks-datasets/definitive-guide/data/flight-data/csv/*.csv", header = True, sep = ',', inferSchema = True)

# %%
flightsAllDF = spark.read.format('csv').load("/databricks-datasets/definitive-guide/data/flight-data/csv/", header = True, sep = ',', inferSchema = True)

# %%
flightsAllDF.count()
# Out:
# Out[15]: 1502

# %% [markdown]
# ## Task 4

# %%
# 4a – Read/load all *.csv files by specifying a custom schema instead of inferring it.
myschema = StructType([
    StructField("dest", StringType()),
    StructField("origin", StringType()),
    StructField("count", LongType())])

flightsAllDF = spark.read.csv("/databricks-datasets/definitive-guide/data/flight-data/csv/*.csv", header = True, sep = ',', schema = myschema)

# %%
# 4b – Print the schema in tree format using printSchema() method of Spark DataFrame.
flightsAllDF.printSchema()
# Out:
# root
#  |-- dest: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- count: long (nullable = true)

# %%
# 4c – Output the count of rows in flightsAllDF and the count of distinct rows in flightsAllDF and explain the difference
print(flightsAllDF.count())
print(flightsAllDF.distinct().count())
# Out:
# 1502
# 1328

# %% [markdown]
# These datasets were originally organized by year. When we combined them into one dataset, we lost the year information, which means that flights between the same two countries over different years are currently treated as duplicates.

# %% [markdown]
# ## Task 5

# %%
# 5a – Use an action command to view all the records of the DataFrame flightsAllDF at the Driver node.
flightsAllDF.collect()
# Out:
# Out[38]: [Row(dest='United States', origin='Romania', numflights=1, year=2010),
#  Row(dest='United States', origin='Ireland', numflights=264, year=2010),
#  Row(dest='United States', origin='India', numflights=69, year=2010),
#  Row(dest='Egypt', origin='United States', numflights=24, year=2010),
#  Row(dest='Equatorial Guinea', origin='United States', numflights=1, year=2010),
#  Row(dest='United States', origin='Singapore', numflights=25, year=2010),
#  Row(dest='United States', origin='Grenada', numflights=54, year=2010),
#  Row(dest='Costa Rica', origin='United States', numflights=477, year=2010),
#  Row(dest='Senegal', origin='United States', numflights=29, year=2010),
#  Row(dest='United States', origin='Marshall Islands', numflights=44, year=2010),
#  Row(dest='Guyana', origin='United States', numflights=17, year=2010),
#  Row(dest='United States', origin='Sint Maarten', numflights=53, year=2010),
#  Row(dest='Malta', origin='United States', numflights=1, year=2010),
#  Row(dest='Bolivia', origin='United States', numflights=46, year=2010),
#  Row(dest='Anguilla', origin='United States', numflights=21, year=2010),
#  Row(dest='Turks and Caicos Islands', origin='United States', numflights=136, year=2010),
#  Row(dest='United States', origin='Afghanistan', numflights=2, year=2010),
#  Row(dest='Saint Vincent and the Grenadines', origin='United States', numflights=1, year=2010),
#  Row(dest='Italy', origin='United States', numflights=390, year=2010),
#  Row(dest='United States', origin='Russia', numflights=156, year=2010),
#  Row(dest='United States', origin='Federated States of Micronesia', numflights=48, year=2010),
#  Row(dest='Pakistan', origin='United States', numflights=9, year=2010),
#  Row(dest='United States', origin='Netherlands', numflights=570, year=2010),
#  Row(dest='Iceland', origin='United States', numflights=118, year=2010),
#  Row(dest='Marshall Islands', origin='United States', numflights=77, year=2010),
#  Row(dest='Luxembourg', origin='United States', numflights=91, year=2010),
#  Row(dest='Honduras', origin='United States', numflights=391, year=2010),
#  Row(dest='The Bahamas', origin='United States', numflights=903, year=2010),
#  Row(dest='El Salvador', origin='United States', numflights=519, year=2010),
#  Row(dest='United States', origin='Senegal', numflights=46, year=2010),
#  Row(dest='Samoa', origin='United States', numflights=28, year=2010),
#  Row(dest='United States', origin='Angola', numflights=18, year=2010),
#  Row(dest='Kazakhstan', origin='United States', numflights=3, year=2010),
#  Row(dest='Switzerland', origin='United States', numflights=315, year=2010),
#  Row(dest='United States', origin='Anguilla', numflights=20, year=2010),
#  Row(dest='Sint Maarten', origin='United States', numflights=61, year=2010),
#  Row(dest='Hong Kong', origin='United States', numflights=252, year=2010),
#  Row(dest='Trinidad and Tobago', origin='United States', numflights=187, year=2010),
#  Row(dest='Latvia', origin='United States', numflights=12, year=2010),
#  Row(dest='United States', origin='Ecuador', numflights=345, year=2010),
#  Row(dest='Slovakia', origin='United States', numflights=1, year=2010),
#  Row(dest='Suriname', origin='United States', numflights=12, year=2010),
#  Row(dest='Mexico', origin='United States', numflights=6200, year=2010),
#  Row(dest='United States', origin='Cyprus', numflights=1, year=2010),
#  Row(dest='Ecuador', origin='United States', numflights=272, year=2010),
#  Row(dest='United States', origin='Bosnia and Herzegovina', numflights=1, year=2010),
#  Row(dest='United States', origin='Portugal', numflights=104, year=2010),
#  Row(dest='United States', origin='Costa Rica', numflights=501, year=2010),
#  Row(dest='United States', origin='Guatemala', numflights=333, year=2010),
#  Row(dest='United States', origin='Suriname', numflights=13, year=2010),
#  Row(dest='Colombia', origin='United States', numflights=785, year=2010),
#  Row(dest='United States', origin='Cape Verde', numflights=18, year=2010),
#  Row(dest='United States', origin='Jamaica', numflights=757, year=2010),
#  Row(dest='United States', origin='Malaysia', numflights=3, year=2010),
#  Row(dest='Norway', origin='United States', numflights=29, year=2010),
#  Row(dest='United States', origin='Morocco', numflights=16, year=2010),
#  Row(dest='Thailand', origin='United States', numflights=16, year=2010),
#  Row(dest='Venezuela', origin='United States', numflights=377, year=2010),
#  Row(dest='United States', origin='Palau', numflights=30, year=2010),
#  Row(dest='United States', origin='Samoa', numflights=28, year=2010),
#  Row(dest='United States', origin='Algeria', numflights=1, year=2010),
#  Row(dest='United States', origin='Venezuela', numflights=341, year=2010),
#  Row(dest='Panama', origin='United States', numflights=355, year=2010),
#  Row(dest='United States', origin='Finland', numflights=20, year=2010),
#  Row(dest='United States', origin='Chile', numflights=176, year=2010),
#  Row(dest='Morocco', origin='United States', numflights=16, year=2010),
#  Row(dest='United States', origin='Greece', numflights=61, year=2010),
#  Row(dest='Antigua and Barbuda', origin='United States', numflights=123, year=2010),
#  Row(dest='Azerbaijan', origin='United States', numflights=1, year=2010),
#  Row(dest='United States', origin='The Bahamas', numflights=959, year=2010),
#  Row(dest='New Zealand', origin='United States', numflights=86, year=2010),
#  Row(dest='Liberia', origin='United States', numflights=1, year=2010),
#  Row(dest='United States', origin='Hong Kong', numflights=293, year=2010),
#  Row(dest='Hungary', origin='United States', numflights=14, year=2010),
#  Row(dest='United States', origin='China', numflights=505, year=2010),
#  Row(dest='United States', origin='Vietnam', numflights=1, year=2010),
#  Row(dest='Sweden', origin='United States', numflights=65, year=2010),
#  Row(dest='United States', origin='Kuwait', numflights=25, year=2010),
#  Row(dest='United States', origin='Dominican Republic', numflights=1150, year=2010),
#  Row(dest='United States', origin='Egypt', numflights=25, year=2010),
#  Row(dest='Israel', origin='United States', numflights=117, year=2010),
#  Row(dest='United States', origin='United States', numflights=348113, year=2010),
#  Row(dest='United States', origin='Luxembourg', numflights=90, year=2010),
#  Row(dest='Ethiopia', origin='United States', numflights=12, year=2010),
#  Row(dest='United States', origin='Poland', numflights=61, year=2010),
#  Row(dest='Martinique', origin='United States', numflights=23, year=2010),
#  Row(dest='Saint Barthelemy', origin='United States', numflights=28, year=2010),
#  Row(dest='United States', origin='Saint Barthelemy', numflights=29, year=2010),
#  Row(dest='United States', origin='Turkey', numflights=87, year=2010),
#  Row(dest='Barbados', origin='United States', numflights=130, year=2010),
#  Row(dest='United States', origin='Estonia', numflights=1, year=2010),
#  Row(dest='United States', origin='Azerbaijan', numflights=1, year=2010),
#  Row(dest='Germany', origin='United States', numflights=1392, year=2010),
#  Row(dest='Kyrgyzstan', origin='United States', numflights=2, year=2010),
#  Row(dest='United States', origin='South Korea', numflights=621, year=2010),
#  Row(dest='United States', origin='El Salvador', numflights=464, year=2010),
#  Row(dest='Ireland', origin='United States', numflights=231, year=2010),
#  Row(dest='United States', origin='Hungary', numflights=15, year=2010),
#  Row(dest='United States', origin='Serbia', numflights=1, year=2010),
#  Row(dest='Malaysia', origin='United States', numflights=1, year=2010),
#  Row(dest='United States', origin='Panama', numflights=363, year=2010),
#  Row(dest='United States', origin='Ethiopia', numflights=12, year=2010),
#  Row(dest='United States', origin='Aruba', numflights=349, year=2010),
#  Row(dest='United States', origin='Thailand', numflights=13, year=2010),
#  Row(dest='United States', origin='Netherlands Antilles', numflights=289, year=2010),
#  Row(dest='United States', origin='Turks and Caicos Islands', numflights=147, year=2010),
#  Row(dest='Cyprus', origin='United States', numflights=2, year=2010),
#  Row(dest='United States', origin='Pakistan', numflights=15, year=2010),
#  Row(dest='United States', origin='Honduras', numflights=393, year=2010),
#  Row(dest='Qatar', origin='United States', numflights=41, year=2010),
#  Row(dest='Fiji', origin='United States', numflights=53, year=2010),
#  Row(dest='Saint Kitts and Nevis', origin='United States', numflights=113, year=2010),
#  Row(dest='Taiwan', origin='United States', numflights=275, year=2010),
#  Row(dest='Haiti', origin='United States', numflights=238, year=2010),
#  Row(dest='Kuwait', origin='United States', numflights=26, year=2010),
#  Row(dest='Canada', origin='United States', numflights=8271, year=2010),
#  Row(dest='Federated States of Micronesia', origin='United States', numflights=46, year=2010),
#  Row(dest='United States', origin='Liberia', numflights=1, year=2010),
#  Row(dest='Jamaica', origin='United States', numflights=733, year=2010),
#  Row(dest='United States', origin='Malta', numflights=2, year=2010),
#  Row(dest='Dominican Republic', origin='United States', numflights=1109, year=2010),
#  Row(dest='Japan', origin='United States', numflights=1383, year=2010),
#  Row(dest='United States', origin='Saint Vincent and the Grenadines', numflights=16, year=2010),
#  Row(dest='United States', origin='Guadeloupe', numflights=33, year=2010),
#  Row(dest='Finland', origin='United States', numflights=24, year=2010),
#  Row(dest='United States', origin='Ukraine', numflights=17, year=2010),
#  Row(dest='United States', origin='France', numflights=776, year=2010),
#  Row(dest='United States', origin='Norway', numflights=36, year=2010),
#  Row(dest='Aruba', origin='United States', numflights=359, year=2010),
#  Row(dest='French Guiana', origin='United States', numflights=4, year=2010),
#  Row(dest='United States', origin='Kiribati', numflights=18, year=2010),
#  Row(dest='India', origin='United States', numflights=66, year=2010),
#  Row(dest='British Virgin Islands', origin='United States', numflights=49, year=2010),
#  Row(dest='United States', origin='Germany', numflights=1406, year=2010),
#  Row(dest='Brazil', origin='United States', numflights=995, year=2010),
#  Row(dest='United States', origin='New Zealand', numflights=71, year=2010),
#  Row(dest='French Polynesia', origin='United States', numflights=38, year=2010),
#  Row(dest='United Arab Emirates', origin='United States', numflights=165, year=2010),
#  Row(dest='Singapore', origin='United States', numflights=25, year=2010),
#  Row(dest='United States', origin='Mexico', numflights=6220, year=2010),
#  Row(dest='Netherlands', origin='United States', numflights=586, year=2010),
#  Row(dest='United States', origin='Sweden', numflights=73, year=2010),
#  Row(dest='United States', origin='Gabon', numflights=1, year=2010),
#  Row(dest='United States', origin='Martinique', numflights=20, year=2010),
#  Row(dest='United States', origin='United Arab Emirates', numflights=156, year=2010),
#  Row(dest='United States', origin='Bulgaria', numflights=2, year=2010),
#  Row(dest='China', origin='United States', numflights=448, year=2010),
#  Row(dest='Denmark', origin='United States', numflights=98, year=2010),
#  Row(dest='United States', origin='Philippines', numflights=116, year=2010),
#  Row(dest='United States', origin='Nicaragua', numflights=181, year=2010),
#  Row(dest='United States', origin='Belgium', numflights=355, year=2010),
#  Row(dest='Peru', origin='United States', numflights=212, year=2010),
#  Row(dest='Argentina', origin='United States', numflights=184, year=2010),
#  Row(dest='Cayman Islands', origin='United States', numflights=247, year=2010),
#  Row(dest='South Africa', origin='United States', numflights=25, year=2010),
#  Row(dest='United States', origin='Iceland', numflights=129, year=2010),
#  Row(dest='United States', origin='Argentina', numflights=159, year=2010),
#  Row(dest='Spain', origin='United States', numflights=422, year=2010),
#  Row(dest='Netherlands Antilles', origin='United States', numflights=286, year=2010),
#  Row(dest='Bermuda', origin='United States', numflights=183, year=2010),
#  Row(dest='United States', origin='Austria', numflights=34, year=2010),
#  Row(dest='United States', origin='Nigeria', numflights=18, year=2010),
#  Row(dest='United States', origin='Bonaire, Sint Eustatius, and Saba', numflights=16, year=2010),
#  Row(dest='Kiribati', origin='United States', numflights=17, year=2010),
#  Row(dest='Saudi Arabia', origin='United States', numflights=42, year=2010),
#  Row(dest='Czech Republic', origin='United States', numflights=21, year=2010),
#  Row(dest='Belgium', origin='United States', numflights=408, year=2010),
#  Row(dest='United States', origin='Israel', numflights=122, year=2010),
#  Row(dest='United States', origin='Bahrain', numflights=1, year=2010),
#  Row(dest='United States', origin='Saint Lucia', numflights=121, year=2010),
#  Row(dest='Afghanistan', origin='United States', numflights=11, year=2010),
#  Row(dest='United States', origin='British Virgin Islands', numflights=47, year=2010),
#  Row(dest='Curacao', origin='United States', numflights=20, year=2010),
#  Row(dest='Georgia', origin='United States', numflights=2, year=2010),
#  Row(dest='United States', origin='Guyana', numflights=20, year=2010),
#  Row(dest='United States', origin='Denmark', numflights=107, year=2010),
#  Row(dest='Philippines', origin='United States', numflights=132, year=2010),
#  Row(dest='Grenada', origin='United States', numflights=65, year=2010),
#  Row(dest='Cape Verde', origin='United States', numflights=18, year=2010),
#  Row(dest='Ukraine', origin='United States', numflights=19, year=2010),
#  Row(dest='United States', origin='Papua New Guinea', numflights=1, year=2010),
#  Row(dest='United States', origin='Saudi Arabia', numflights=54, year=2010),
#  Row(dest='Russia', origin='United States', numflights=152, year=2010),
#  Row(dest='Guatemala', origin='United States', numflights=386, year=2010),
#  Row(dest='Saint Lucia', origin='United States', numflights=116, year=2010),
#  Row(dest='Paraguay', origin='United States', numflights=90, year=2010),
#  Row(dest='United States', origin='Curacao', numflights=14, year=2010),
#  Row(dest='United States', origin='Taiwan', numflights=252, year=2010),
#  Row(dest='United States', origin='South Africa', numflights=15, year=2010),
#  Row(dest='Turkey', origin='United States', numflights=75, year=2010),
#  Row(dest='United Kingdom', origin='United States', numflights=1629, year=2010),
#  Row(dest='United States', origin='Greenland', numflights=2, year=2010),
#  Row(dest='United States', origin='Spain', numflights=442, year=2010),
#  Row(dest='Cuba', origin='United States', numflights=243, year=2010),
#  Row(dest='United States', origin='Italy', numflights=433, year=2010),
#  Row(dest='United States', origin='Switzerland', numflights=334, year=2010),
#  Row(dest='Dominica', origin='United States', numflights=28, year=2010),
#  Row(dest='United States', origin='Japan', numflights=1307, year=2010),
#  Row(dest='Portugal', origin='United States', numflights=102, year=2010),
#  Row(dest='United States', origin='Brazil', numflights=578, year=2010),
#  Row(dest='Bahrain', origin='United States', numflights=30, year=2010),
#  Row(dest='United States', origin='Peru', numflights=284, year=2010),
#  Row(dest='Vietnam', origin='United States', numflights=1, year=2010),
#  Row(dest='United States', origin='United Kingdom', numflights=1503, year=2010),
#  Row(dest='United States', origin='Belize', numflights=118, year=2010),
#  Row(dest='Belize', origin='United States', numflights=121, year=2010),
#  Row(dest='United States', origin='Ghana', numflights=28, year=2010),
#  Row(dest='United States', origin='Indonesia', numflights=1, year=2010),
#  Row(dest='United States', origin='Fiji', numflights=51, year=2010),
#  Row(dest='United States', origin='Canada', numflights=8305, year=2010),
#  Row(dest='United States', origin='French Polynesia', numflights=38, year=2010),
#  Row(dest='United States', origin='Antigua and Barbuda', numflights=121, year=2010),
#  Row(dest='United States', origin='Burkina Faso', numflights=1, year=2010),
#  Row(dest='Nicaragua', origin='United States', numflights=178, year=2010),
#  Row(dest='United States', origin='Latvia', numflights=13, year=2010),
#  Row(dest='United States', origin='Dominica', numflights=32, year=2010),
#  Row(dest='United States', origin='Czech Republic', numflights=22, year=2010),
#  Row(dest='United States', origin='Australia', numflights=216, year=2010),
#  Row(dest='Austria', origin='United States', numflights=36, year=2010),
#  Row(dest='United States', origin='Cook Islands', numflights=12, year=2010),
#  Row(dest='Jordan', origin='United States', numflights=50, year=2010),
#  Row(dest='Palau', origin='United States', numflights=31, year=2010),
#  Row(dest='Uganda', origin='United States', numflights=2, year=2010),
#  Row(dest='United States', origin='Cameroon', numflights=1, year=2010),
#  Row(dest='South Korea', origin='United States', numflights=683, year=2010),
#  Row(dest='Angola', origin='United States', numflights=14, year=2010),
#  Row(dest='Ghana', origin='United States', numflights=27, year=2010),
#  Row(dest='Guadeloupe', origin='United States', numflights=40, year=2010),
#  Row(dest='France', origin='United States', numflights=774, year=2010),
#  Row(dest='United States', origin='Kyrgyzstan', numflights=12, year=2010),
#  Row(dest='Poland', origin='United States', numflights=62, year=2010),
#  Row(dest='Nigeria', origin='United States', numflights=16, year=2010),
#  Row(dest='United States', origin='Uruguay', numflights=24, year=2010),
#  Row(dest='Greenland', origin='United States', numflights=2, year=2010),
#  Row(dest='Chile', origin='United States', numflights=166, year=2010),
#  Row(dest='United States', origin='Bermuda', numflights=180, year=2010),
#  Row(dest='United States', origin='Cuba', numflights=235, year=2010),
#  Row(dest='United States', origin='Colombia', numflights=832, year=2010),
#  Row(dest='United States', origin='Qatar', numflights=40, year=2010),
#  Row(dest='United States', origin='Barbados', numflights=119, year=2010),
#  Row(dest='Australia', origin='United States', numflights=290, year=2010),
#  Row(dest='United States', origin='Jordan', numflights=51, year=2010),
#  Row(dest='United States', origin='Cayman Islands', numflights=251, year=2010),
#  Row(dest='United States', origin='Trinidad and Tobago', numflights=200, year=2010),
#  Row(dest='United States', origin='Bolivia', numflights=39, year=2010),
#  Row(dest='United States', origin='Slovakia', numflights=1, year=2010),
#  Row(dest='Uruguay', origin='United States', numflights=54, year=2010),
#  Row(dest='Cook Islands', origin='United States', numflights=13, year=2010),
#  Row(dest='United States', origin='Saint Kitts and Nevis', numflights=127, year=2010),
#  Row(dest='Bulgaria', origin='United States', numflights=1, year=2010),
#  Row(dest='United States', origin='French Guiana', numflights=1, year=2010),
#  Row(dest='United States', origin='Haiti', numflights=226, year=2010),
#  Row(dest='United States', origin='Uganda', numflights=1, year=2010),
#  Row(dest='Bonaire, Sint Eustatius, and Saba', origin='United States', numflights=16, year=2010),
#  Row(dest='Greece', origin='United States', numflights=50, year=2010),
#  Row(dest='United States', origin='Romania', numflights=15, year=2015),
#  Row(dest='United States', origin='Croatia', numflights=1, year=2015),
#  Row(dest='United States', origin='Ireland', numflights=344, year=2015),
#  Row(dest='Egypt', origin='United States', numflights=15, year=2015),
#  Row(dest='United States', origin='India', numflights=62, year=2015),
#  Row(dest='United States', origin='Singapore', numflights=1, year=2015),
#  Row(dest='United States', origin='Grenada', numflights=62, year=2015),
#  Row(dest='Costa Rica', origin='United States', numflights=588, year=2015),
#  Row(dest='Senegal', origin='United States', numflights=40, year=2015),
#  Row(dest='Moldova', origin='United States', numflights=1, year=2015),
#  Row(dest='United States', origin='Sint Maarten', numflights=325, year=2015),
#  Row(dest='United States', origin='Marshall Islands', numflights=39, year=2015),
#  Row(dest='Guyana', origin='United States', numflights=64, year=2015),
#  Row(dest='Malta', origin='United States', numflights=1, year=2015),
#  Row(dest='Anguilla', origin='United States', numflights=41, year=2015),
#  Row(dest='Bolivia', origin='United States', numflights=30, year=2015),
#  Row(dest='United States', origin='Paraguay', numflights=6, year=2015),
#  Row(dest='Algeria', origin='United States', numflights=4, year=2015),
#  Row(dest='Turks and Caicos Islands', origin='United States', numflights=230, year=2015),
#  Row(dest='United States', origin='Gibraltar', numflights=1, year=2015),
#  Row(dest='Saint Vincent and the Grenadines', origin='United States', numflights=1, year=2015),
#  Row(dest='Italy', origin='United States', numflights=382, year=2015),
#  Row(dest='United States', origin='Federated States of Micronesia', numflights=69, year=2015),
#  Row(dest='United States', origin='Russia', numflights=161, year=2015),
#  Row(dest='Pakistan', origin='United States', numflights=12, year=2015),
#  Row(dest='United States', origin='Netherlands', numflights=660, year=2015),
#  Row(dest='Iceland', origin='United States', numflights=181, year=2015),
#  Row(dest='Marshall Islands', origin='United States', numflights=42, year=2015),
#  Row(dest='Luxembourg', origin='United States', numflights=155, year=2015),
#  Row(dest='Honduras', origin='United States', numflights=362, year=2015),
#  Row(dest='The Bahamas', origin='United States', numflights=955, year=2015),
#  Row(dest='United States', origin='Senegal', numflights=42, year=2015),
#  Row(dest='El Salvador', origin='United States', numflights=561, year=2015),
#  Row(dest='Samoa', origin='United States', numflights=25, year=2015),
#  Row(dest='United States', origin='Angola', numflights=13, year=2015),
#  Row(dest='Switzerland', origin='United States', numflights=294, year=2015),
#  Row(dest='United States', origin='Anguilla', numflights=38, year=2015),
#  Row(dest='Sint Maarten', origin='United States', numflights=325, year=2015),
#  Row(dest='Hong Kong', origin='United States', numflights=332, year=2015),
#  Row(dest='Trinidad and Tobago', origin='United States', numflights=211, year=2015),
#  Row(dest='Latvia', origin='United States', numflights=19, year=2015),
#  Row(dest='United States', origin='Ecuador', numflights=300, year=2015),
#  Row(dest='Suriname', origin='United States', numflights=1, year=2015),
#  Row(dest='Mexico', origin='United States', numflights=7140, year=2015),
#  Row(dest='United States', origin='Cyprus', numflights=1, year=2015),
#  Row(dest='Ecuador', origin='United States', numflights=268, year=2015),
#  Row(dest='United States', origin='Portugal', numflights=134, year=2015),
#  Row(dest='United States', origin='Costa Rica', numflights=608, year=2015),
#  Row(dest='United States', origin='Guatemala', numflights=318, year=2015),
#  Row(dest='United States', origin='Suriname', numflights=34, year=2015),
#  Row(dest='Colombia', origin='United States', numflights=873, year=2015),
#  Row(dest='United States', origin='Cape Verde', numflights=14, year=2015),
#  Row(dest='United States', origin='Jamaica', numflights=712, year=2015),
#  Row(dest='Norway', origin='United States', numflights=121, year=2015),
#  Row(dest='United States', origin='Malaysia', numflights=3, year=2015),
#  Row(dest='United States', origin='Morocco', numflights=19, year=2015),
#  Row(dest='Thailand', origin='United States', numflights=3, year=2015),
#  Row(dest='United States', origin='Samoa', numflights=25, year=2015),
#  Row(dest='Venezuela', origin='United States', numflights=290, year=2015),
#  Row(dest='United States', origin='Palau', numflights=31, year=2015),
#  Row(dest='United States', origin='Venezuela', numflights=246, year=2015),
#  Row(dest='Panama', origin='United States', numflights=510, year=2015),
#  Row(dest='Antigua and Barbuda', origin='United States', numflights=126, year=2015),
#  Row(dest='United States', origin='Chile', numflights=185, year=2015),
#  Row(dest='Morocco', origin='United States', numflights=15, year=2015),
#  Row(dest='United States', origin='Finland', numflights=28, year=2015),
#  Row(dest='Azerbaijan', origin='United States', numflights=21, year=2015),
#  Row(dest='United States', origin='Greece', numflights=23, year=2015),
#  Row(dest='United States', origin='The Bahamas', numflights=986, year=2015),
#  Row(dest='New Zealand', origin='United States', numflights=111, year=2015),
#  Row(dest='Liberia', origin='United States', numflights=2, year=2015),
#  Row(dest='United States', origin='Hong Kong', numflights=414, year=2015),
#  Row(dest='Hungary', origin='United States', numflights=2, year=2015),
#  Row(dest='United States', origin='China', numflights=920, year=2015),
#  Row(dest='United States', origin='Vietnam', numflights=2, year=2015),
#  Row(dest='Burkina Faso', origin='United States', numflights=1, year=2015),
#  Row(dest='Sweden', origin='United States', numflights=118, year=2015),
#  Row(dest='United States', origin='Kuwait', numflights=28, year=2015),
#  Row(dest='United States', origin='Dominican Republic', numflights=1420, year=2015),
#  Row(dest='United States', origin='Egypt', numflights=1
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# ow(dest='United States', origin='Argentina', numflights=152, year=2011),
#  Row(dest='United States', origin='Iceland', numflights=138, year=2011),
#  Row(dest='Spain', origin='United States', numflights=445, year=2011),
#  Row(dest='Bermuda', origin='United States', numflights=191, year=2011),
#  Row(dest='United States', origin='Austria', numflights=34, year=2011),
#  Row(dest='United States', origin='Nigeria', numflights=26, year=2011),
#  Row(dest='United States', origin='Bonaire, Sint Eustatius, and Saba', numflights=49, year=2011),
#  Row(dest='Kiribati', origin='United States', numflights=28, year=2011),
#  Row(dest='Czech Republic', origin='United States', numflights=23, year=2011),
#  Row(dest='Saudi Arabia', origin='United States', numflights=83, year=2011),
#  Row(dest='Macau', origin='United States', numflights=2, year=2011),
#  Row(dest='Belgium', origin='United States', numflights=376, year=2011),
#  Row(dest='United States', origin='Israel', numflights=126, year=2011),
#  Row(dest='United States', origin='Saint Lucia', numflights=102, year=2011),
#  Row(dest='United States', origin='Bahrain', numflights=2, year=2011),
#  Row(dest='United States', origin='British Virgin Islands', numflights=65, year=2011),
#  Row(dest='Afghanistan', origin='United States', numflights=8, year=2011),
#  Row(dest='Curacao', origin='United States', numflights=106, year=2011),
#  Row(dest='Georgia', origin='United States', numflights=1, year=2011),
#  Row(dest='United States', origin='Guyana', numflights=29, year=2011),
#  Row(dest='Philippines', origin='United States', numflights=127, year=2011),
#  Row(dest='United States', origin='Denmark', numflights=103, year=2011),
#  Row(dest='Grenada', origin='United States', numflights=67, year=2011),
#  Row(dest='Cape Verde', origin='United States', numflights=13, year=2011),
#  Row(dest='Ukraine', origin='United States', numflights=15, year=2011),
#  Row(dest='United States', origin='Papua New Guinea', numflights=1, year=2011),
#  Row(dest='Russia', origin='United States', numflights=199, year=2011),
#  Row(dest='United States', origin='Saudi Arabia', numflights=77, year=2011),
#  Row(dest='Guatemala', origin='United States', numflights=407, year=2011),
#  Row(dest='Saint Lucia', origin='United States', numflights=102, year=2011),
#  Row(dest='Paraguay', origin='United States', numflights=85, year=2011),
#  Row(dest='United States', origin='Curacao', numflights=97, year=2011),
#  Row(dest='United States', origin='Taiwan', numflights=231, year=2011),
#  Row(dest='United States', origin='South Africa', numflights=21, year=2011),
#  Row(dest='Togo', origin='United States', numflights=1, year=2011),
#  Row(dest='Turkey', origin='United States', numflights=104, year=2011),
#  Row(dest='United Kingdom', origin='United States', numflights=1726, year=2011),
#  Row(dest='Romania', origin='United States', numflights=4, year=2011),
#  Row(dest='United States', origin='Greenland', numflights=2, year=2011),
#  Row(dest='United States', origin='Spain', numflights=472, year=2011),
#  Row(dest='Cuba', origin='United States', numflights=320, year=2011),
#  Row(dest='United States', origin='Italy', numflights=447, year=2011),
#  Row(dest='United States', origin='Switzerland', numflights=319, year=2011),
#  Row(dest='Dominica', origin='United States', numflights=25, year=2011),
#  Row(dest='United States', origin='Japan', numflights=1412, year=2011),
#  Row(dest='Portugal', origin='United States', numflights=95, year=2011),
#  Row(dest='United States', origin='Brazil', numflights=575, year=2011),
#  Row(dest='Bahrain', origin='United States', numflights=40, year=2011),
#  Row(dest='United States', origin='Peru', numflights=288, year=2011),
#  Row(dest='Vietnam', origin='United States', numflights=1, year=2011),
#  Row(dest='United States', origin='United Kingdom', numflights=1649, year=2011),
#  Row(dest='United States', origin='Belize', numflights=112, year=2011),
#  Row(dest='Belize', origin='United States', numflights=113, year=2011),
#  Row(dest='United States', origin='Ghana', numflights=39, year=2011),
#  Row(dest='Mauritania', origin='United States', numflights=1, year=2011),
#  Row(dest='Saint Martin', origin='United States', numflights=1, year=2011),
#  Row(dest='United States', origin='Indonesia', numflights=1, year=2011),
#  Row(dest='United States', origin='Fiji', numflights=48, year=2011),
#  Row(dest='United States', origin='Mauritania', numflights=1, year=2011),
#  Row(dest='United States', origin='Canada', numflights=8650, year=2011),
#  Row(dest='United States', origin='Antigua and Barbuda', numflights=152, year=2011),
#  Row(dest='United States', origin='French Polynesia', numflights=36, year=2011),
#  Row(dest='Nicaragua', origin='United States', numflights=180, year=2011),
#  Row(dest='Namibia', origin='United States', numflights=1, year=2011),
#  Row(dest='United States', origin='Latvia', numflights=12, year=2011),
#  Row(dest='United States', origin='Dominica', numflights=29, year=2011),
#  Row(dest='United States', origin='Czech Republic', numflights=25, year=2011),
#  Row(dest='United States', origin='Australia', numflights=231, year=2011),
#  Row(dest='United States', origin='Cook Islands', numflights=12, year=2011),
#  Row(dest='Austria', origin='United States', numflights=34, year=2011),
#  Row(dest='Palau', origin='United States', numflights=41, year=2011),
#  Row(dest='Jordan', origin='United States', numflights=42, year=2011),
#  Row(dest='South Korea', origin='United States', numflights=713, year=2011),
#  Row(dest='Ghana', origin='United States', numflights=39, year=2011),
#  Row(dest='Angola', origin='United States', numflights=13, year=2011),
#  Row(dest='Guadeloupe', origin='United States', numflights=33, year=2011),
#  Row(dest='France', origin='United States', numflights=876, year=2011),
#  Row(dest='Nigeria', origin='United States', numflights=31, year=2011),
#  Row(dest='Poland', origin='United States', numflights=39, year=2011),
#  Row(dest='United States', origin='Uruguay', numflights=27, year=2011),
#  Row(dest='Greenland', origin='United States', numflights=1, year=2011),
#  Row(dest='Chile', origin='United States', numflights=178, year=2011),
#  Row(dest='United States', origin='Bermuda', numflights=196, year=2011),
#  Row(dest='Lebanon', origin='United States', numflights=1, year=2011),
#  Row(dest='United States', origin='Cuba', numflights=326, year=2011),
#  Row(dest='United States', origin='Colombia', numflights=777, year=2011),
#  Row(dest='United States', origin='Barbados', numflights=125, year=2011),
#  Row(dest='United States', origin='Qatar', numflights=48, year=2011),
#  Row(dest='Australia', origin='United States', numflights=280, year=2011),
#  Row(dest='United States', origin='Cayman Islands', numflights=262, year=2011),
#  Row(dest='United States', origin='Jordan', numflights=45, year=2011),
#  Row(dest='United States', origin='Bolivia', numflights=51, year=2011),
#  Row(dest='United States', origin='Trinidad and Tobago', numflights=213, year=2011),
#  Row(dest='Uruguay', origin='United States', numflights=50, year=2011),
#  Row(dest='Cook Islands', origin='United States', numflights=12, year=2011),
#  Row(dest='United States', origin='Saint Kitts and Nevis', numflights=120, year=2011),
#  Row(dest='Bulgaria', origin='United States', numflights=4, year=2011),
#  Row(dest='United States', origin='French Guiana', numflights=11, year=2011),
#  Row(dest='United States', origin='Haiti', numflights=197, year=2011),
#  Row(dest='Bonaire, Sint Eustatius, and Saba', origin='United States', numflights=50, year=2011),
#  Row(dest='Greece', origin='United States', numflights=38, year=2011),
#  Row(dest='United States', origin='Romania', numflights=12, year=2013),
#  Row(dest='United States', origin='Croatia', numflights=1, year=2013),
#  Row(dest='United States', origin='Ireland', numflights=266, year=2013),
#  Row(dest='Egypt', origin='United States', numflights=13, year=2013),
#  Row(dest='United States', origin='India', numflights=60, year=2013),
#  Row(dest='Equatorial Guinea', origin='United States', numflights=1, year=2013),
#  Row(dest='United States', origin='Niger', numflights=1, year=2013),
#  Row(dest='United States', origin='Singapore', numflights=22, year=2013),
#  Row(dest='United States', origin='Grenada', numflights=40, year=2013),
#  Row(dest='Costa Rica', origin='United States', numflights=509, year=2013),
#  Row(dest='Senegal', origin='United States', numflights=28, year=2013),
#  Row(dest='Guyana', origin='United States', numflights=34, year=2013),
#  Row(dest='United States', origin='Sint Maarten', numflights=260, year=2013),
#  Row(dest='United States', origin='Marshall Islands', numflights=33, year=2013),
#  Row(dest='Bolivia', origin='United States', numflights=33, year=2013),
#  Row(dest='Anguilla', origin='United States', numflights=22, year=2013),
#  Row(dest='United States', origin='Paraguay', numflights=15, year=2013),
#  Row(dest='Algeria', origin='United States', numflights=2, year=2013),
#  Row(dest='Turks and Caicos Islands', origin='United States', numflights=181, year=2013),
#  Row(dest='Saint Vincent and the Grenadines', origin='United States', numflights=4, year=2013),
#  Row(dest='Lithuania', origin='United States', numflights=1, year=2013),
#  Row(dest='Pakistan', origin='United States', numflights=14, year=2013),
#  Row(dest='Italy', origin='United States', numflights=327, year=2013),
#  Row(dest='United States', origin='Russia', numflights=167, year=2013),
#  Row(dest='United States', origin='Federated States of Micronesia', numflights=62, year=2013),
#  Row(dest='United States', origin='Netherlands', numflights=618, year=2013),
#  Row(dest='Iceland', origin='United States', numflights=146, year=2013),
#  Row(dest='Marshall Islands', origin='United States', numflights=50, year=2013),
#  Row(dest='Luxembourg', origin='United States', numflights=160, year=2013),
#  Row(dest='Honduras', origin='United States', numflights=423, year=2013),
#  Row(dest='Rwanda', origin='United States', numflights=1, year=2013),
#  Row(dest='The Bahamas', origin='United States', numflights=865, year=2013),
#  Row(dest='El Salvador', origin='United States', numflights=551, year=2013),
#  Row(dest='United States', origin='Senegal', numflights=32, year=2013),
#  Row(dest='Samoa', origin='United States', numflights=25, year=2013),
#  Row(dest='United States', origin='Angola', numflights=12, year=2013),
#  Row(dest='Kazakhstan', origin='United States', numflights=2, year=2013),
#  Row(dest='Switzerland', origin='United States', numflights=288, year=2013),
#  Row(dest='United States', origin='Anguilla', numflights=18, year=2013),
#  Row(dest='United States', origin='Mali', numflights=1, year=2013),
#  Row(dest='Sint Maarten', origin='United States', numflights=271, year=2013),
#  Row(dest='Hong Kong', origin='United States', numflights=282, year=2013),
#  Row(dest='Trinidad and Tobago', origin='United States', numflights=183, year=2013),
#  Row(dest='Latvia', origin='United States', numflights=29, year=2013),
#  Row(dest='United States', origin='Ecuador', numflights=307, year=2013),
#  Row(dest='Suriname', origin='United States', numflights=15, year=2013),
#  Row(dest='Mexico', origin='United States', numflights=6372, year=2013),
#  Row(dest='Ecuador', origin='United States', numflights=252, year=2013),
#  Row(dest='United States', origin='Portugal', numflights=126, year=2013),
#  Row(dest='United States', origin='Costa Rica', numflights=549, year=2013),
#  Row(dest='United States', origin='Guatemala', numflights=331, year=2013),
#  Row(dest='United States', origin='Suriname', numflights=21, year=2013),
#  Row(dest='Colombia', origin='United States', numflights=798, year=2013),
#  Row(dest='United States', origin='Cape Verde', numflights=15, year=2013),
#  Row(dest='Norway', origin='United States', numflights=48, year=2013),
#  Row(dest='United States', origin='Jamaica', numflights=599, year=2013),
#  Row(dest='United States', origin='Malaysia', numflights=1, year=2013),
#  Row(dest='United States', origin='Morocco', numflights=16, year=2013),
#  Row(dest='Thailand', origin='United States', numflights=2, year=2013),
#  Row(dest='Burundi', origin='United States', numflights=1, year=2013),
#  Row(dest='Venezuela', origin='United States', numflights=350, year=2013),
#  Row(dest='United States', origin='Samoa', numflights=25, year=2013),
#  Row(dest='United States', origin='Palau', numflights=35, year=2013),
#  Row(dest='United States', origin='Venezuela', numflights=295, year=2013),
#  Row(dest='Panama', origin='United States', numflights=418, year=2013),
#  Row(dest='United States', origin='Finland', numflights=15, year=2013),
#  Row(dest='Morocco', origin='United States', numflights=18, year=2013),
#  Row(dest='Antigua and Barbuda', origin='United States', numflights=123, year=2013),
#  Row(dest='United States', origin='Chile', numflights=171, year=2013),
#  Row(dest='Azerbaijan', origin='United States', numflights=3, year=2013),
#  Row(dest='United States', origin='Greece', numflights=14, year=2013),
#  Row(dest='United States', origin='The Bahamas', numflights=897, year=2013),
#  Row(dest='New Zealand', origin='United States', numflights=114, year=2013),
#  Row(dest='United States', origin='Hong Kong', numflights=344, year=2013),
#  Row(dest='Hungary', origin='United States', numflights=1, year=2013),
#  Row(dest='United States', origin='China', numflights=614, year=2013),
#  Row(dest='United States', origin='Kuwait', numflights=24, year=2013),
#  Row(dest='Sweden', origin='United States', numflights=70, year=2013),
#  Row(dest='United States', origin='Egypt', numflights=12, year=2013),
#  Row(dest='United States', origin='Dominican Republic', numflights=1119, year=2013),
#  Row(dest='Israel', origin='United States', numflights=119, year=2013),
#  Row(dest='United States', origin='United States', numflights=343132, year=2013),
#  Row(dest='United States', origin='Luxembourg', numflights=134, year=2013),
#  Row(dest='Ethiopia', origin='United States', numflights=12, year=2013),
#  Row(dest='United States', origin='Poland', numflights=37, year=2013),
#  Row(dest='Martinique', origin='United States', numflights=26, year=2013),
#  Row(dest='United States', origin='Zimbabwe', numflights=2, year=2013),
#  Row(dest='United States', origin='Saint Barthelemy', numflights=58, year=2013),
#  Row(dest='Saint Barthelemy', origin='United States', numflights=67, year=2013),
#  Row(dest='United States', origin='Turkey', numflights=100, year=2013),
#  Row(dest='Barbados', origin='United States', numflights=97, year=2013),
#  Row(dest='Germany', origin='United States', numflights=1423, year=2013),
#  Row(dest='Kyrgyzstan', origin='United States', numflights=1, year=2013),
#  Row(dest='United States', origin='South Korea', numflights=687, year=2013),
#  Row(dest='United States', origin='El Salvador', numflights=466, year=2013),
#  Row(dest='Ireland', origin='United States', numflights=255, year=2013),
#  Row(dest='Malaysia', origin='United States', numflights=2, year=2013),
#  Row(dest='United States', origin='Aruba', numflights=344, year=2013),
#  Row(dest='United States', origin='Panama', numflights=419, year=2013),
#  Row(dest='United States', origin='Ethiopia', numflights=12, year=2013),
#  Row(dest='United States', origin='Turks and Caicos Islands', numflights=178, year=2013),
#  Row(dest='United States', origin='Pakistan', numflights=12, year=2013),
#  Row(dest='Cyprus', origin='United States', numflights=2, year=2013),
#  Row(dest='United States', origin='Honduras', numflights=392, year=2013),
#  Row(dest='Fiji', origin='United States', numflights=34, year=2013),
#  Row(dest='Qatar', origin='United States', numflights=71, year=2013),
#  Row(dest='Saint Kitts and Nevis', origin='United States', numflights=99, year=2013),
#  Row(dest='Kuwait', origin='United States', numflights=24, year=2013),
#  Row(dest='Haiti', origin='United States', numflights=199, year=2013),
#  Row(dest='Taiwan', origin='United States', numflights=243, year=2013),
#  Row(dest='Canada', origin='United States', numflights=7860, year=2013),
#  Row(dest='Federated States of Micronesia', origin='United States', numflights=53, year=2013),
#  Row(dest='Jamaica', origin='United States', numflights=581, year=2013),
#  Row(dest='Dominican Republic', origin='United States', numflights=1068, year=2013),
#  Row(dest='Japan', origin='United States', numflights=1613, year=2013),
#  Row(dest='United States', origin='Saint Vincent and the Grenadines', numflights=10, year=2013),
#  Row(dest='Finland', origin='United States', numflights=17, year=2013),
#  Row(dest='United States', origin='Ukraine', numflights=4, year=2013),
#  Row(dest='United States', origin='Guadeloupe', numflights=42, year=2013),
#  Row(dest='United States', origin='France', numflights=848, year=2013),
#  Row(dest='United States', origin='Norway', numflights=46, year=2013),
#  Row(dest='Aruba', origin='United States', numflights=352, year=2013),
#  Row(dest='French Guiana', origin='United States', numflights=7, year=2013),
#  Row(dest='United States', origin='Kiribati', numflights=29, year=2013),
#  Row(dest='Zimbabwe', origin='United States', numflights=2, year=2013),
#  Row(dest='India', origin='United States', numflights=61, year=2013),
#  Row(dest='British Virgin Islands', origin='United States', numflights=101, year=2013),
#  Row(dest='United States', origin='Germany', numflights=1402, year=2013),
#  Row(dest='United States', origin='New Zealand', numflights=77, year=2013),
#  Row(dest='Brazil', origin='United States', numflights=912, year=2013),
#  Row(dest='Saint Helena, Ascension, and Tristan da Cunha', origin='United States', numflights=1, year=2013),
#  Row(dest='United States', origin='Cambodia', numflights=3, year=2013),
#  Row(dest='French Polynesia', origin='United States', numflights=43, year=2013),
#  Row(dest='United Arab Emirates', origin='United States', numflights=202, year=2013),
#  Row(dest='Singapore', origin='United States', numflights=21, year=2013),
#  Row(dest='Tanzania', origin='United States', numflights=2, year=2013),
#  Row(dest='United States', origin='Mexico', numflights=6354, year=2013),
#  Row(dest='Netherlands', origin='United States', numflights=640, year=2013),
#  Row(dest='United States', origin='Sweden', numflights=73, year=2013),
#  Row(dest='United States', origin='Martinique', numflights=24, year=2013),
#  Row(dest='United States', origin='United Arab Emirates', numflights=187, year=2013),
#  Row(dest='Denmark', origin='United States', numflights=104, year=2013),
#  Row(dest='China', origin='United States', numflights=543, year=2013),
#  Row(dest='United States', origin='Nicaragua', numflights=185, year=2013),
#  Row(dest='United States', origin='Philippines', numflights=112, year=2013),
#  Row(dest='United States', origin='Belgium', numflights=193, year=2013),
#  Row(dest='Nepal', origin='United States', numflights=1, year=2013),
#  Row(dest='Libya', origin='United States', numflights=1, year=2013),
#  Row(dest='Argentina', origin='United States', numflights=176, year=2013),
#  Row(dest='Peru', origin='United States', numflights=255, year=2013),
#  Row(dest='Cayman Islands', origin='United States', numflights=274, year=2013),
#  Row(dest='South Africa', origin='United States', numflights=24, year=2013),
#  Row(dest='United States', origin='Iceland', numflights=151, year=2013),
#  Row(dest='United States', origin='Argentina', numflights=140, year=2013),
#  Row(dest='Spain', origin='United States', numflights=370, year=2013),
#  Row(dest='Bermuda', origin='United States', numflights=163, year=2013),
#  Row(dest='United States', origin='Nigeria', numflights=49, year=2013),
#  Row(dest='United States', origin='Austria', numflights=39, year=2013),
#  Row(dest='United States', origin='Bonaire, Sint Eustatius, and Saba', numflights=54, year=2013),
#  Row(dest='Kiribati', origin='United States', numflights=29, year=2013),
#  Row(dest='Saudi Arabia', origin='United States', numflights=86, year=2013),
#  Row(dest='Czech Republic', origin='United States', numflights=10, year=2013),
#  Row(dest='Macau', origin='United States', numflights=2, year=2013),
#  Row(dest='Belgium', origin='United States', numflights=265, year=2013),
#  Row(dest='United States', origin='Israel', numflights=107, year=2013),
#  Row(dest='United States', origin='Saint Lucia', numflights=92, year=2013),
#  Row(dest='Sierra Leone', origin='United States', numflights=1, year=2013),
#  Row(dest='United States', origin='Bahrain', numflights=1, year=2013),
#  Row(dest='United States', origin='British Virgin Islands', numflights=94, year=2013),
#  Row(dest='United States', origin='Saint Helena, Ascension, and Tristan da Cunha', numflights=2, year=2013),
#  Row(dest='Curacao', origin='United States', numflights=97, year=2013),
#  Row(dest='United States', origin='Denmark', numflights=106, year=2013),
#  Row(dest='United States', origin='Guyana', numflights=52, year=2013),
#  Row(dest='Philippines', origin='United States', numflights=136, year=2013),
#  Row(dest='Grenada', origin='United States', numflights=42, year=2013),
#  Row(dest='Cape Verde', origin='United States', numflights=21, year=2013),
#  Row(dest='Ukraine', origin='United States', numflights=4, year=2013),
#  Row(dest='Russia', origin='United States', numflights=194, year=2013),
#  Row(dest='United States', origin='Saudi Arabia', numflights=84, year=2013),
#  Row(dest='Guatemala', origin='United States', numflights=376, year=2013),
#  Row(dest='Saint Lucia', origin='United States', numflights=91, year=2013),
#  Row(dest='Paraguay', origin='United States', numflights=75, year=2013),
#  Row(dest='United States', origin='Curacao', numflights=89, year=2013),
#  Row(dest='United States', origin='Taiwan', numflights=235, year=2013),
#  Row(dest='United States', origin='South Africa', numflights=26, year=2013),
#  Row(dest='Niger', origin='United States', numflights=1, year=2013),
#  Row(dest='Turkey', origin='United States', numflights=99, year=2013),
#  Row(dest='United Kingdom', origin='United States', numflights=1802, year=2013),
#  Row(dest='Romania', origin='United States', numflights=14, year=2013),
#  Row(dest='United States', origin='Greenland', numflights=3, year=2013),
#  Row(dest='Papua New Guinea', origin='United States', numflights=2, year=2013),
#  Row(dest='United States', origin='Spain', numflights=377, year=2013),
#  Row(dest='United States', origin='Italy', numflights=333, year=2013),
#  Row(dest='Cuba', origin='United States', numflights=337, year=2013),
#  Row(dest='United States', origin='Switzerland', numflights=285, year=2013),
#  Row(dest='Dominica', origin='United States', numflights=19, year=2013),
#  Row(dest='Portugal', origin='United States', numflights=116, year=2013),
#  Row(dest='United States', origin='Japan', numflights=1476, year=2013),
#  Row(dest='United States', origin='Brazil', numflights=510, year=2013),
#  Row(dest='Bahrain', origin='United States', numflights=50, year=2013),
#  Row(dest='United States', origin='Peru', numflights=300, year=2013),
#  Row(dest='Indonesia', origin='United States', numflights=1, year=2013),
#  Row(dest='United States', origin='United Kingdom', numflights=1711, year=2013),
#  Row(dest='United States', origin='Belize', numflights=127, year=2013),
#  Row(dest='Belize', origin='United States', numflights=137, year=2013),
#  Row(dest='Kenya', origin='United States', numflights=1, year=2013),
#  Row(dest='United States', origin='Ghana', numflights=16, year=2013),
#  Row(dest='United States', origin='Fiji', numflights=30, year=2013),
#  Row(dest='United States', origin='Canada', numflights=7983, year=2013),
#  Row(dest='United States', origin='French Polynesia', numflights=40, year=2013),
#  Row(dest='United States', origin='Antigua and Barbuda', numflights=123, year=2013),
#  Row(dest='Brunei', origin='United States', numflights=1, year=2013),
#  Row(dest='Nicaragua', origin='United States', numflights=178, year=2013),
#  Row(dest='United States', origin='Latvia', numflights=12, year=2013),
#  Row(dest='United States', origin='Dominica', numflights=25, year=2013),
#  Row(dest='United States', origin='Czech Republic', numflights=9, year=2013),
#  Row(dest='United States', origin='Cook Islands', numflights=12, year=2013),
#  Row(dest='Austria', origin='United States', numflights=35, year=2013),
#  Row(dest='United States', origin='Australia', numflights=222, year=2013),
#  Row(dest='Jordan', origin='United States', numflights=74, year=2013),
#  Row(dest='Palau', origin='United States', numflights=35, year=2013),
#  Row(dest='South Korea', origin='United States', numflights=842, year=2013),
#  Row(dest='Angola', origin='United States', numflights=12, year=2013),
#  Row(dest='Ghana', origin='United States', numflights=16, year=2013),
#  Row(dest='New Caledonia', origin='United States', numflights=1, year=2013),
#  Row(dest='Guadeloupe', origin='United States', numflights=41, year=2013),
#  Row(dest='France', origin='United States', numflights=837, year=2013),
#  Row(dest='Poland', origin='United States', numflights=40, year=2013),
#  Row(dest='Nigeria', origin='United States', numflights=58, year=2013),
#  Row(dest='United States', origin='Uruguay', numflights=20, year=2013),
#  Row(dest='Greenland', origin='United States', numflights=1, year=2013),
#  Row(dest='Chile', origin='United States', numflights=147, year=2013),
#  Row(dest='United States', origin='Bermuda', numflights=166, year=2013),
#  Row(dest='Lebanon', origin='United States', numflights=1, year=2013),
#  ...]

# %%
# 5b – Use three different action commands to view just three rows of the distributed DF
flightsAllDF.show(n=3)
flightsAllDF.limit(3).show()
flightsAllDF.head(3)
# Out:
# +-------------+-------+-----+
# |         dest| origin|count|
# +-------------+-------+-----+
# |United States|Romania|    1|
# |United States|Ireland|  264|
# |United States|  India|   69|
# +-------------+-------+-----+
# only showing top 3 rows
#
# +-------------+-------+-----+
# |         dest| origin|count|
# +-------------+-------+-----+
# |United States|Romania|    1|
# |United States|Ireland|  264|
# |United States|  India|   69|
# +-------------+-------+-----+
#
# Out[16]: [Row(dest='United States', origin='Romania', count=1),
#  Row(dest='United States', origin='Ireland', count=264),
#  Row(dest='United States', origin='India', count=69)]

# %%
# 5c – Print the type of the first row of the DataFrame. 
type(flightsAllDF.first())
# Out:
# Out[17]: pyspark.sql.types.Row

# %% [markdown]
# ## Task 6

# %%
# 6a – Create a new DF (say flightsAllDF_1) with two changes as described below – rename an existing column ‘count’ to ‘numflights’, and add a new column with the filename as values
flightsAllDF_1 = flightsAllDF.withColumnRenamed("count", "numflights").withColumn("filename", F.input_file_name())

# %%
# 6b – Repeat task 6a. using select() method of Spark DataFrame and column expressions
flightsAllDF_1 = flightsAllDF.select('dest', "origin", F.col("count").alias("numflights"), F.input_file_name().alias("filename"))

# %%
# 6c – Output 5 records showing just the numflights and filename columns in table form
flightsAllDF_1.select("numflights", "filename").show(5, truncate = False)
# Out:
# +----------+--------------------------------------------------------------------------------+
# |numflights|filename                                                                        |
# +----------+--------------------------------------------------------------------------------+
# |1         |dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2010-summary.csv|
# |264       |dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2010-summary.csv|
# |69        |dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2010-summary.csv|
# |24        |dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2010-summary.csv|
# |1         |dbfs:/databricks-datasets/definitive-guide/data/flight-data/csv/2010-summary.csv|
# +----------+--------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
# 6d – Print out just the column names of FlightsAllDF (there should only be four column names).
flightsAllDF = flightsAllDF_1

flightsAllDF.columns
# Out:
# Out[8]: ['dest', 'origin', 'numflights', 'filename']

# %% [markdown]
# ## Task 7

# %%
# 7a – Add a new column to flightsAllDF called ‘year’ (cast as type integer), and populate it with just the year extracted from the column filename above. Save this is a new DF called flightsAllDF_2 
flightsAllDF_2 = flightsAllDF.select('*', F.regexp_extract('filename', '/(\d+)-', 1).alias("year").cast(IntegerType()))

flightsAllDF_2.show(5)
# Out:
# +-----------------+-------------+----------+--------------------+----+
# |             dest|       origin|numflights|            filename|year|
# +-----------------+-------------+----------+--------------------+----+
# |    United States|      Romania|         1|dbfs:/databricks-...|2010|
# |    United States|      Ireland|       264|dbfs:/databricks-...|2010|
# |    United States|        India|        69|dbfs:/databricks-...|2010|
# |            Egypt|United States|        24|dbfs:/databricks-...|2010|
# |Equatorial Guinea|United States|         1|dbfs:/databricks-...|2010|
# +-----------------+-------------+----------+--------------------+----+
# only showing top 5 rows

# %%
# 7b – Re-save this new DF flightsAllDF_2 back in flightsAllDF. Drop column 'filename'
flightsAllDF = flightsAllDF_2.drop("filename")

# %%
# 7c – View 5 records in table format showing all columns of flightsAllDF
flightsAllDF.show(5)
# Out:
# +-----------------+-------------+----------+----+
# |             dest|       origin|numflights|year|
# +-----------------+-------------+----------+----+
# |    United States|      Romania|         1|2010|
# |    United States|      Ireland|       264|2010|
# |    United States|        India|        69|2010|
# |            Egypt|United States|        24|2010|
# |Equatorial Guinea|United States|         1|2010|
# +-----------------+-------------+----------+----+
# only showing top 5 rows

# %%
# 7d – View the data types of the columns of flightsAllDF using a DataFrame attribute
flightsAllDF.dtypes
# Out:
# Out[25]: [('dest', 'string'),
#  ('origin', 'string'),
#  ('numflights', 'bigint'),
#  ('year', 'int')]

# %% [markdown]
# ## Task 8

# %%
# 8a – sort flightsAllDF by ‘dest’ in ascending order and ‘numflights’ in descending order. View the top 10 records
flightsAllDF.orderBy(["dest", "numflights"], ascending = [True, False]).show(10)
# Out:
# +-----------+-------------+----------+----+
# |       dest|       origin|numflights|year|
# +-----------+-------------+----------+----+
# |Afghanistan|United States|        11|2010|
# |Afghanistan|United States|         8|2011|
# |Afghanistan|United States|         5|2012|
# |    Algeria|United States|         9|2014|
# |    Algeria|United States|         4|2015|
# |    Algeria|United States|         2|2013|
# |     Angola|United States|        15|2015|
# |     Angola|United States|        14|2010|
# |     Angola|United States|        13|2014|
# |     Angola|United States|        13|2011|
# +-----------+-------------+----------+----+
# only showing top 10 rows

# %% [markdown]
# ## Task 9

# %%
# 9a – How many distinct destinations are in the dataset?
flightsAllDF.select(F.countDistinct("dest")).show()
# Out:
# +--------------------+
# |count(DISTINCT dest)|
# +--------------------+
# |                 167|
# +--------------------+

# %%
# 9b – How many distinct combinations of destination and year are there?
print(flightsAllDF.select("dest", "year").distinct().count())
# Out:
# 772

# %% [markdown]
# ## Task 10

# %%
# 10a – How many records of flightsAllDF contain either Japan or South Korea as the destination?
print(flightsAllDF.filter((F.col("dest") == 'Japan') | (F.col("dest") == 'South Korea')).count())
# Out:
# 12

# %%
# 10b – How many total flights did United States send to South Korea in 2013? 
flightsAllDF.filter((F.col("origin") == 'United States') & (F.col("dest") == 'South Korea') & (F.col("year") == 2013)).show()

# total flights is 842
# Out:
# +-----------+-------------+----------+----+
# |       dest|       origin|numflights|year|
# +-----------+-------------+----------+----+
# |South Korea|United States|       842|2013|
# +-----------+-------------+----------+----+

# %% [markdown]
# ## Task 11

# %%
# 11a – Display a bar chart of the number of domestic flights(Y) vs year(X), sorted by year in ascending order.
display(flightsAllDF.filter((F.col("origin") == 'United States') & (F.col("dest") == 'United States')).sort("year"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dest</th><th>origin</th><th>numflights</th><th>year</th></tr></thead><tbody><tr><td>United States</td><td>United States</td><td>348113</td><td>2010</td></tr><tr><td>United States</td><td>United States</td><td>352742</td><td>2011</td></tr><tr><td>United States</td><td>United States</td><td>347452</td><td>2012</td></tr><tr><td>United States</td><td>United States</td><td>343132</td><td>2013</td></tr><tr><td>United States</td><td>United States</td><td>358354</td><td>2014</td></tr><tr><td>United States</td><td>United States</td><td>370002</td><td>2015</td></tr></tbody></table></div>

# %% [markdown]
# ## Task 12

# %%
# 12a – How many total flights (domestic and international) are flown in each of the 6 years? Print the output sorted in descending order of the sum of number of flights column.
flightsAllDF.groupby("year").sum("numflights").sort("sum(numflights)", ascending = False).show()
# Out:
# +----+---------------+
# |year|sum(numflights)|
# +----+---------------+
# |2015|         453316|
# |2014|         436855|
# |2011|         428426|
# |2010|         422269|
# |2012|         422180|
# |2013|         417869|
# +----+---------------+

# %% [markdown]
# ## Task 13

# %%
# 13a – What is the total number of international flights that flew to the United States in each of the 6 years?
# Obtain a table with the column of flight count values named as totalflightsin instead of the default, and sort the results in ascending order of totalflightsin.
inUSADF = flightsAllDF.filter((F.col("origin") != 'United States') & (F.col("dest") == 'United States')).groupby("year").sum("numflights").withColumnRenamed("sum(numflights)", "totalflightsin")

display(inUSADF.sort("totalflightsin"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>totalflightsin</th></tr></thead><tbody><tr><td>2010</td><td>36819</td></tr><tr><td>2013</td><td>36830</td></tr><tr><td>2012</td><td>36890</td></tr><tr><td>2011</td><td>37763</td></tr><tr><td>2014</td><td>38833</td></tr><tr><td>2015</td><td>41350</td></tr></tbody></table></div>

# %%
# 13b – In what years were there more international flights flying to the United States than international flights that flew out of the United States? Include:
# i. year – year of data, in ascending order
# ii. totalflightsin – total number of international flights to the US as destination
# iii. totalflightout - total number of international flights from the US as origin
# iv. morein – a boolean that is set to True if totalflightsin > totalflightsout

outUSADF = flightsAllDF.filter((F.col("origin") == 'United States') & (F.col("dest") != 'United States')).groupby("year").sum("numflights").withColumnRenamed("sum(numflights)", "totalflightsout")

USADF = inUSADF.join(outUSADF, on = 'year', how = 'inner')

USADF.select('*', F.col("totalflightsin") > F.col("totalflightsout")).withColumnRenamed("(totalflightsin > totalflightsout)", "morein").sort("year").show()
# Out:
# +----+--------------+---------------+------+
# |year|totalflightsin|totalflightsout|morein|
# +----+--------------+---------------+------+
# |2010|         36819|          37337| false|
# |2011|         37763|          37921| false|
# |2012|         36890|          37838| false|
# |2013|         36830|          37907| false|
# |2014|         38833|          39668| false|
# |2015|         41350|          41964| false|
# +----+--------------+---------------+------+

# %% [markdown]
# ## Task 14

# %%
# 14a – For the rows that contain United States as destination but NOT as origin (i.e. international flights into the USA) compute and print the following summary statistics for the column numflights – sum, avg, max - for each of the 6 years.
# The output should have columns named, year, sumflightstoUS, avgflightstoUS, maxflightstoUS.
# Ascending sort the DataFrame by year. 

flightsAllDF.filter((F.col("origin") != 'United States') & (F.col("dest") == 'United States')).groupby("year").agg(F.sum("numflights").alias("sumflightstoUS"), F.mean("numflights").alias("avgflightstoUS"), F.max("numflights").alias("maxflightstoUS")).sort("year").show()
# Out:
# +----+--------------+------------------+--------------+
# |year|sumflightstoUS|    avgflightstoUS|maxflightstoUS|
# +----+--------------+------------------+--------------+
# |2010|         36819| 283.2230769230769|          8305|
# |2011|         37763| 299.7063492063492|          8650|
# |2012|         36890| 312.6271186440678|          8097|
# |2013|         36830| 320.2608695652174|          7983|
# |2014|         38833| 331.9059829059829|          8177|
# |2015|         41350|333.46774193548384|          8483|
# +----+--------------+------------------+--------------+
